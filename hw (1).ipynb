# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 700)
plt.plot(x, np.cos(x), 'o')
plt.plot(x, np.cos(2*x), 'o')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 150)
k= 1 
k1=-20
plt.plot(x, np.cos(k*x))
plt.plot(x, np.cos(k1*x))
